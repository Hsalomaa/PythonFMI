# %%
import requests
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as ticker
import os
from pprint import pprint
import json
import urllib2
import xml.etree.ElementTree as ET
import csv
import pandas as pd
from datetime import datetime, timedelta
import pymongo

# %%
f = urllib2.urlopen('http://api.wunderground.com/api/10f51b471553d661/geolookup/conditions/q/IA/Kuopio.json')
json_string = f.read()
parsed_json = json.loads(json_string)
location = parsed_json['location']['city']
temp_c = parsed_json['current_observation']['temp_c']
print "Current temperature in %s is: %s" %(location, temp_c)
f.close
# Out:
# Current temperature in Kuopio is: 7.6
# <bound method addinfourl.close of <addinfourl at 4519452184 whose fp = <socket._fileobject object at 0x10cda18d0>>>

# %%
r = requests.get('http://data.fmi.fi/fmi-apikey/25b57e29-e541-4ce1-8645-fb5e4e47ed40/wfs?request=getFeature&storedquery_id=fmi::observations::weather::simple&place=kumpula,Helsinki&timestep=30&parameters=temperature&starttime=2010-01-01T00:00:00Z')
xmlstring = r.content

root = ET.fromstring(xmlstring)

outfile = open("temperature.csv", "w")
writer = csv.writer(outfile)

header = ("timestamp", "temperature")
writer.writerow(header)

for child in root.iter('{http://xml.fmi.fi/schema/wfs/2.0}BsWfsElement'):
    parameter_name = child.find('{http://xml.fmi.fi/schema/wfs/2.0}ParameterName').text
    if parameter_name != "temperature":
        continue
    
    parameter_value = child.find('{http://xml.fmi.fi/schema/wfs/2.0}ParameterValue').text
    timestamp = child.find('{http://xml.fmi.fi/schema/wfs/2.0}Time').text
    row = (timestamp, parameter_value)
    writer.writerow(row)
    
outfile.close()

# %%
df = pd.read_csv("temperature.csv")

last_ts = (df['timestamp'].iloc[-1])

ts = datetime.strptime(last_ts, "%Y-%m-%dT%H:%M:%SZ")
ts += timedelta(minutes=30)

string_ts = datetime.strftime(ts, "%Y-%m-%dT%H:%M:%SZ")

starttime = '&starttime=' + string_ts

api_key = '25b57e29-e541-4ce1-8645-fb5e4e47ed40'
url = 'http://data.fmi.fi/fmi-apikey/' + api_key + '/wfs?request=getFeature&storedquery_id=fmi::observations::weather::simple&place=kumpula,Helsinki' + starttime + '&timestep=30&parameters=temperature'

running_r = requests.get(url)
running_s = running_r.content

r_root = ET.fromstring(running_s)

updatefile = open("temperature.csv", "a")
update_writer = csv.writer(updatefile)

for child in r_root.iter('{http://xml.fmi.fi/schema/wfs/2.0}BsWfsElement'):
    parameter_name = child.find('{http://xml.fmi.fi/schema/wfs/2.0}ParameterName').text
    if parameter_name != "temperature":
        continue
    
    parameter_value = child.find('{http://xml.fmi.fi/schema/wfs/2.0}ParameterValue').text
    timestamp = child.find('{http://xml.fmi.fi/schema/wfs/2.0}Time').text
    row = (timestamp, parameter_value)
    update_writer.writerow(row)
    
updatefile.close()

# %%
# Setting starting date and time for FMI Rest api call
startts = "2010-01-01T00:00:00Z"

# Creates variables for looping and 7-days periods and months
# FMI uses 7 days period for 30min measures and that is why we need to use these variables
starttime = datetime.strptime(startts, "%Y-%m-%dT%H:%M:%SZ")
next_month = datetime(starttime.year + (starttime.month / 12), ((starttime.month % 12) + 1), 1)
# Stopdate is user defined variable. This is a last month that will be fetched
stopdate = datetime.strptime("2010-02-01T00:00:00Z", "%Y-%m-%dT%H:%M:%SZ")
runningweek = starttime
continuedate = starttime

# Loop structure for REST api call - first while only checks if stopdate is reached
# second while creates 7 days rest api call for temperatures
# Check for is running date is past stopdate
while (continuedate <= stopdate):
    
    # Naming file name for saving data: year-month-first day
    savename = datetime(runningweek.year, runningweek.month, 1)
    filename = datetime.strftime(savename, "%Y-%m-%d")
    
    # Open file for writing data
    f = open(filename + ".csv", "w")
    writer = csv.writer(f)
    
    # Writing header to csv-file
    header = ("timestamp", "temperature")
    writer.writerow(header)
    
    # Checking if month has changed, if so closing file and save next month number
    while(runningweek <= next_month):
        
        # creating starttime for url
        start_string = datetime.strftime(runningweek, "%Y-%m-%dT%H:%M:%SZ")
        starttime = '&starttime=' + start_string
        
        # creating endtime for url
        ending = runningweek + timedelta(days=7)
        
        # Checking if ending date is bigger than next_month, if so taking next_month datetime minus 30 mins
        # this will prevent over writing from monthly data
        if(ending > next_month):
            ending = next_month - timedelta(minutes=30)
            end_string = datetime.strftime(ending, "%Y-%m-%dT%H:%M:%SZ")
            endtime = '&endtime=' + end_string
        else:
            end_string = datetime.strftime(ending, "%Y-%m-%dT%H:%M:%SZ")
            endtime = '&endtime=' + end_string
                
        # creating rest api url
        api_key = '25b57e29-e541-4ce1-8645-fb5e4e47ed40'
        url = 'http://data.fmi.fi/fmi-apikey/' + api_key + '/wfs?request=getFeature&storedquery_id=fmi::observations::weather::simple&place=kumpula,Helsinki' + starttime + endtime + '&timestep=30&parameters=temperature'

        # sending requests and saving content from it
        running_r = requests.get(url)
        running_s = running_r.content

        r_root = ET.fromstring(running_s)
            

        #updatefile = open("temperature.csv", "a")
        update_writer = csv.writer(f)
        
        # iterating xml data and finding temperature measure parameter
        for child in r_root.iter('{http://xml.fmi.fi/schema/wfs/2.0}BsWfsElement'):
            parameter_name = child.find('{http://xml.fmi.fi/schema/wfs/2.0}ParameterName').text
            if parameter_name != "temperature":
                continue
        # writing timestamp and parameter_value to file
            parameter_value = child.find('{http://xml.fmi.fi/schema/wfs/2.0}ParameterValue').text
            timestamp = child.find('{http://xml.fmi.fi/schema/wfs/2.0}Time').text
            #print "%s;%s" % (timestamp, parameter_value)
            row = (timestamp, parameter_value)
            update_writer.writerow(row)
    
        # adding new startdate for loop 7 days + 30min
        runningweek = runningweek + timedelta(days=7) + timedelta(minutes=30)
        
    else:
        runningweek = next_month
        next_month = datetime(next_month.year + (next_month.month / 12), ((next_month.month % 12) + 1), 1)
        continuedate = runningweek
        f.close()
else :
    print("loop completed")

# just clearing variables for sure
next_month = None
runningweek = None
continuedate = None
# Out:
# loop completed

# %%
client=pymongo.MongoClient('localhost',27017)
db=client.HelWeather
serverStatusResult = db.command("serverStatus")
print(serverStatusResult)
# Out:
# {u'process': u'mongod', u'pid': 97254L, u'connections': {u'current': 3, u'available': 5731, u'totalCreated': 5}, u'locks': {u'Metadata': {u'acquireCount': {u'w': 1L}}, u'Global': {u'acquireCount': {u'r': 1768L, u'W': 3L, u'w': 8L}}, u'Collection': {u'acquireCount': {u'r': 618L}}, u'Database': {u'acquireCount': {u'R': 7L, u'r': 626L, u'W': 8L}}}, u'storageEngine': {u'readOnly': False, u'supportsCommittedReads': True, u'name': u'wiredTiger', u'persistent': True}, u'globalLock': {u'totalTime': 489569000L, u'currentQueue': {u'total': 0, u'writers': 0, u'readers': 0}, u'activeClients': {u'total': 9, u'writers': 0, u'readers': 0}}, u'extra_info': {u'note': u'fields vary by platform', u'page_faults': 174}, u'uptimeEstimate': 489L, u'uptime': 489.0, u'network': {u'physicalBytesOut': 9958L, u'numRequests': 73L, u'bytesOut': 9958L, u'physicalBytesIn': 3419L, u'bytesIn': 3419L}, u'uptimeMillis': 489579L, u'version': u'3.4.9', u'mem': {u'resident': 20, u'supported': True, u'virtual': 3170, u'mappedWithJournal': 0, u'mapped': 0, u'bits': 64}, u'opcountersRepl': {u'getmore': 0, u'insert': 0, u'update': 0, u'command': 0, u'query': 0, u'delete': 0}, u'wiredTiger': {u'data-handle': {u'session dhandles swept': 0, u'connection sweeps': 48, u'connection sweep dhandles removed from hash list': 3, u'connection data handles currently active': 11, u'connection sweep dhandles closed': 0, u'session sweep attempts': 16, u'connection sweep candidate became referenced': 0, u'connection sweep time-of-death sets': 3}, u'reconciliation': {u'fast-path pages deleted': 0, u'split objects currently awaiting free': 0, u'split bytes currently awaiting free': 0, u'pages deleted': 0, u'page reconciliation calls for eviction': 0, u'page reconciliation calls': 11}, u'cache': {u'unmodified pages evicted': 0, u'eviction server evicting pages': 0, u'tracked dirty pages in the cache': 0, u'overflow values cached in memory': 0, u'eviction calls to get a page found queue empty after locking': 0, u'internal pages split during eviction': 0, u'application threads page write from cache to disk time (usecs)': 0, u'page split during eviction deepened the tree': 0, u'leaf pages split during eviction': 0, u'pages walked for eviction': 0, u'percentage overhead': 8, u'pages evicted by application threads': 0, u'tracked dirty bytes in the cache': 0, u'maximum page size at eviction': 0, u'failed eviction of pages that exceeded the in-memory maximum': 0, u'application threads page write from cache to disk count': 0, u'eviction worker thread stable number': 0, u'pages evicted because they exceeded the in-memory maximum': 0, u'tracked bytes belonging to leaf pages in the cache': 110906, u'eviction server candidate queue empty when topping up': 0, u'bytes written from cache': 43260, u'force re-tuning of eviction workers once in a while': 0, u'eviction empty score': 0, u'eviction server slept, because we did not make progress with eviction': 0, u'pages queued for urgent eviction': 0, u'eviction walks abandoned': 0, u'eviction currently operating in aggressive mode': 0, u'application threads page read from disk to cache count': 10, u'tracked bytes belonging to internal pages in the cache': 45989, u'bytes currently in the cache': 156895, u'pages selected for eviction unable to be evicted': 0, u'hazard pointer maximum array length': 0, u'lookaside table remove calls': 0, u'in-memory page passed criteria to be split': 0, u'eviction state': 16, u'checkpoint blocked page eviction': 0, u'pages queued for urgent eviction during walk': 0, u'eviction calls to get a page found queue empty': 12, u'application threads page read from disk to cache time (usecs)': 78895, u'pages written from cache': 11, u'eviction calls to get a page': 12, u'modified pages evicted by application threads': 0, u'pages seen by eviction walk': 0, u'eviction worker thread evicting pages': 0, u'bytes read into cache': 78812, u'page written requiring lookaside records': 0, u'hazard pointer blocked page eviction': 0, u'lookaside t ...

# %%
weather = db.HelWeather
temp_data = {
    'ts': [datetime.strptime('2017-11-01', '%Y-%m-%d'), datetime.strptime('2017-11-02', '%Y-%m-%d'), datetime.strptime('2017-11-03', '%Y-%m-%d')],
    'temperature': [5,6,4]
}

result = weather.insert_many(temp_data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-e5732f2d972c> in <module>()
#       5 }
#       6
# ----> 7 result = weather.insert_many(temp_data)
#
# /Users/hsalomaa/anaconda/envs/analysis/lib/python2.7/site-packages/pymongo/collection.pyc in insert_many(self, documents, ordered, bypass_document_validation)
#     708
#     709         blk = _Bulk(self, ordered, bypass_document_validation)
# --> 710         blk.ops = [doc for doc in gen()]
#     711         blk.execute(self.write_concern.document)
#     712         return InsertManyResult(inserted_ids, self.write_concern.acknowledged)
#
# /Users/hsalomaa/anaconda/envs/analysis/lib/python2.7/site-packages/pymongo/collection.pyc in gen()
#     700             """A generator that validates documents and handles _ids."""
#     701             for document in documents:
# --> 702                 common.validate_is_document_type("document", document)
#     703                 if not isinstance(document, RawBSONDocument):
#     704                     if "_id" not in document:
#
# /Users/hsalomaa/anaconda/envs/analysis/lib/python2.7/site-packages/pymongo/common.pyc in validate_is_document_type(option, value)
#     405                         "bson.raw_bson.RawBSONDocument, or "
#     406                         "a type that inherits from "
# --> 407                         "collections.MutableMapping" % (option,))
#     408
#     409
#
# TypeError: document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping

# %%
# This will create list of year-months csv-files. startts is starting date and stopdate is the last month to create

startts = "2010-01-01T00:00:00Z"

next_month = datetime.strptime(startts, "%Y-%m-%dT%H:%M:%SZ")
stopdate = datetime.strptime("2012-01-01T00:00:00Z", "%Y-%m-%dT%H:%M:%SZ")
month_list =[]

while (next_month <= stopdate):
    month_list.append(next_month.strftime('%Y-%m-%d'))
    next_month = datetime(next_month.year + (next_month.month / 12), ((next_month.month % 12) + 1), 1)


for item in month_list:
    f = open(item + ".csv", "w")
    f.close()

month_list = []

# %%
# Setting starting date and time for FMI Rest api call
startts = "2010-01-01T00:00:00Z"

# Creates variables for looping and 7-days periods and months
# FMI uses 7 days period for 30min measures and that is why we need to use these variables
starttime = datetime.strptime(startts, "%Y-%m-%dT%H:%M:%SZ")
next_month = datetime(starttime.year + (starttime.month / 12), ((starttime.month % 12) + 1), 1)
# Stopdate is user defined variable. This is a last month that will be fetched
stopdate = datetime.strptime("2010-02-01T00:00:00Z", "%Y-%m-%dT%H:%M:%SZ")
runningweek = starttime
continuedate = starttime

# Loop structure for REST api call - first while only checks if stopdate is reached
# second while creates 7 days rest api call for temperatures
# Check for is running date is past stopdate
while (continuedate <= stopdate):
    
    # Naming file name for saving data: year-month-first day
    savename = datetime(runningweek.year, runningweek.month, 1)
    filename = datetime.strftime(savename, "%Y-%m-%d")
    
    # Open file for writing data
    #f = open(filename + ".csv", "w")
    #writer = csv.writer(f)
    
    # Writing header to csv-file
    #header = ("timestamp", "temperature")
    #writer.writerow(header)
    
    # Checking if month has changed, if so closing file and save next month number
    while(runningweek <= next_month):
        
        # creating starttime for url
        start_string = datetime.strftime(runningweek, "%Y-%m-%dT%H:%M:%SZ")
        starttime = '&starttime=' + start_string
        
        # creating endtime for url
        ending = runningweek + timedelta(days=7)
        
        # Checking if ending date is bigger than next_month, if so taking next_month datetime minus 30 mins
        # this will prevent over writing from monthly data
        if(ending > next_month):
            ending = next_month - timedelta(minutes=30)
            end_string = datetime.strftime(ending, "%Y-%m-%dT%H:%M:%SZ")
            endtime = '&endtime=' + end_string
        else:
            end_string = datetime.strftime(ending, "%Y-%m-%dT%H:%M:%SZ")
            endtime = '&endtime=' + end_string
                
        # creating rest api url
        api_key = '25b57e29-e541-4ce1-8645-fb5e4e47ed40'
        url = 'http://data.fmi.fi/fmi-apikey/' + api_key + '/wfs?request=getFeature&storedquery_id=fmi::observations::weather::simple&place=kumpula,Helsinki' + starttime + endtime + '&timestep=30&parameters=temperature,humidity,winddirection,windspeedms'

        # sending requests and saving content from it
        running_r = requests.get(url)
        running_s = running_r.content

        r_root = ET.fromstring(running_s)
            

        #updatefile = open("temperature.csv", "a")
        #update_writer = csv.writer(f)
        
        measure = {}
        new_ts = starttime
        
        # iterating xml data and finding temperature measure parameter
        for child in r_root.iter('{http://xml.fmi.fi/schema/wfs/2.0}BsWfsElement'):
            parameter_name = str(child.find('{http://xml.fmi.fi/schema/wfs/2.0}ParameterName').text)
        #    if parameter_name != "temperature":
        #        continue
        # writing timestamp and parameter_value to file
            parameter_value = child.find('{http://xml.fmi.fi/schema/wfs/2.0}ParameterValue').text
            timestamp = child.find('{http://xml.fmi.fi/schema/wfs/2.0}Time').text
            measure['timestamp'] = timestamp
            measure['parameter_name'] = parameter_name
            measure['parameter_value'] = parameter_value
            
            print(measure)
            #print "%s;%s;%s" % (timestamp, parameter_name, parameter_value)
            
            #row = (timestamp, parameter_value)
            #update_writer.writerow(row)
    
        # adding new startdate for loop 7 days + 30min
        runningweek = runningweek + timedelta(days=7) + timedelta(minutes=30)
        
    else:
        runningweek = next_month
        next_month = datetime(next_month.year + (next_month.month / 12), ((next_month.month % 12) + 1), 1)
        continuedate = runningweek
        f.close()
else :
    print("loop completed")

# just clearing variables for sure
next_month = None
runningweek = None
continuedate = None
# Out:
# {'timestamp': '2010-01-01T00:00:00Z', 'parameter_value': '-10.6', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-01T00:00:00Z', 'parameter_value': '88.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-01T00:00:00Z', 'parameter_value': '41.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-01T00:00:00Z', 'parameter_value': '5.2', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-01T00:30:00Z', 'parameter_value': '-10.6', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-01T00:30:00Z', 'parameter_value': '89.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-01T00:30:00Z', 'parameter_value': '42.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-01T00:30:00Z', 'parameter_value': '5.6', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-01T01:00:00Z', 'parameter_value': '-10.6', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-01T01:00:00Z', 'parameter_value': '88.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-01T01:00:00Z', 'parameter_value': '41.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-01T01:00:00Z', 'parameter_value': '5.5', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-01T01:30:00Z', 'parameter_value': '-10.6', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-01T01:30:00Z', 'parameter_value': '88.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-01T01:30:00Z', 'parameter_value': '42.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-01T01:30:00Z', 'parameter_value': '4.3', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-01T02:00:00Z', 'parameter_value': '-10.5', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-01T02:00:00Z', 'parameter_value': '88.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-01T02:00:00Z', 'parameter_value': '39.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-01T02:00:00Z', 'parameter_value': '4.7', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-01T02:30:00Z', 'parameter_value': '-10.6', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-01T02:30:00Z', 'parameter_value': '90.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-01T02:30:00Z', 'parameter_value': '34.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-01T02:30:00Z', 'parameter_value': '4.1', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-01T03:00:00Z', 'parameter_value': '-10.7', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-01T03:00:00Z', 'parameter_value': '89.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-01T03:00:00Z', 'parameter_value': '42.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-01T03:00:00Z', 'parameter_value': '5.5', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-01T03:30:00Z', 'parameter_value': '-10.8', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-01T03:30:00Z', 'parameter_value': '89.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-01T03:30:00Z', 'parameter_value': '43.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-01T03:30:00Z', 'parameter_value': '5.6', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-01T04:00:00Z', 'parameter_value': '-10.8', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-01T04:00:00Z', 'parameter_value': '89.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-01T04:00:00Z', 'parameter_value': '44.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-01T04:00:00Z', 'parameter_value': '5.4', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-01T04:30:00Z', 'parameter_value': '-11.1', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-01T04:30:00Z', 'parameter_value': '88.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-01T04:30:00Z', 'parameter_value': '43.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-01T04:30:00Z', 'parameter_value': '5.0', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-01T05:00:00Z', 'parameter_value': '-11.1', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-01T05:00:00Z', 'parameter_value': '88.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-01T05:00:00Z', 'parameter_value': '41.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-01T05:00:00Z', 'parameter_value': '5.9', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-01T05:30:00Z', 'parameter_value': '-11.2', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-01T05:30:00Z', 'parameter_value': '88.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-01T05:30:00Z', 'parameter_value': '40.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-01T05:30:00Z', 'parameter_value': '5.2', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-01T06:00:00Z', 'parameter_value': '-11.4', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-01T06:00:00Z', 'parameter_value': '89.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-01T06:00:00Z', 'parameter_value': '36.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-01T06:00:00Z', 'parameter_value': '5.6', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-01T06:30:00Z', 'parameter_value': '-11.8', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-01T06:30:00Z', 'parameter_value': '88.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-01T06:30:00Z', 'parameter_value': '35.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-01T06:30:00Z', 'parameter_value': '5.5', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-01T07:00:00Z', 'parameter_value': '-12.1', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-01T07:00:00Z', 'parameter_value': '87.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-01T07:00:00Z', 'parameter_value': '39.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-01T07:00:00Z', 'parameter_value': '6.1', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-01T07:30:00Z', 'parameter_value': '-12.3', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-01T07:30:00Z', 'parameter_value': '87.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-01T07:30:00Z', 'parameter_value': '43.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-01T07:30:00Z', 'parameter_value': '5.1', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-01T08:00:00Z', 'parameter_value': '-12.5', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-01T08:00:00Z', 'parameter_value': '87.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-01T08:00:00Z', 'parameter_value': '43.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-01T08:00:00Z', 'parameter_value': '4.7', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-01T08:30:00Z', 'parameter_value': '-13.0', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-01T08:30:00Z', 'parameter_value': '87.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-01T08:30:00Z', 'parameter_value': '47.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-01T08:30:00Z', 'parameter_value': '4.0', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-01T09:00:00Z', 'parameter_value': '-13.3', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-01T09:00:00Z', 'parameter_value': '87.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-01T09:00:00Z', 'parameter_value': '40.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-01T09:00:00Z', 'parameter_value': '3.0', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-01T09:30:00Z', 'parameter_value': '-13.2', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-01T09:30:00Z', 'parameter_value': '86.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-01T09:30:00Z', 'parameter_value': '37.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-01T09:30:00Z', 'parameter_value': '3.4', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-01T10:00:00Z', 'parameter_value': '-13.1', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-01T10:00:00Z', 'parameter_value': '85.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-01T10:00:00Z', 'parameter_value': '26.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-01T10:00:00Z', 'parameter_value': '4.5', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-01T10:30:00Z', 'parameter_value': '-13.2', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-01T10:30:00Z', 'parameter_value': '85.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-01T10:30:00Z', 'parameter_value': '31.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-01T10:30:00Z', 'parameter_value': '3.6', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-01T11:00:00Z', 'parameter_value': '-13.0', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-01T11:00:00Z', 'parameter_value': '84.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-01T11:00:00Z', 'parameter_value': '29.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-01T11:00:00Z', 'parameter_value': '4.6', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-01T11:30:00Z', 'parameter_value': '-13.1', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-01T11:30:00Z', 'parameter_value': '84.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-01T11:30:00Z', 'parameter_value': '29.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-01T11:30:00Z', 'parameter_value': '5.7', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-01T12:00:00Z', 'parameter_value': '-13.2', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-01T12:00:00Z', 'parameter_value': '83.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-01T12:00:00Z', 'parameter_value': '27.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-01T12:00:00Z', 'parameter_value': '4.8', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-01T12:30:00Z', 'parameter_value': '-13.3', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-01T12:30:00Z', 'parameter_value': '84.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-01T12:30:00Z', 'parameter_value': '29.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-01T12:30:00Z', 'parameter_value': '5.0', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-01T13:00:00Z', 'parameter_value': '-13.4', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-01T13:00:00Z', 'parameter_value': '84.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-01T13:00:00Z', 'parameter_value': '27.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-01T13:00:00Z', 'parameter_value': '5.2', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-01T13:30:00Z', 'parameter_value': '-13.7', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-01T13:30:00Z', 'parameter_value': '84.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-01T13:30:00Z', 'parameter_value': '28.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-01T13:30:00Z', 'parameter_value': '4.8', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-01T14:00:00Z', 'parameter_value': '-13.9', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-01T14:00:00Z', 'parameter_value': '85.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-01T14:00:00Z', 'parameter_value': '28.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-01T14:00:00Z', 'parameter_value': '5.3', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-01T14:30:00Z', 'parameter_value': '-14.2', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-01T14:30:00Z', 'parameter_value': '85.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-01T14:30:00Z', 'parameter_value': '30.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-01T14:30:00Z', 'parameter_value': '5.0', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-01T15:00:00Z', 'parameter_value': '-14.5', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-01T15:00:00Z', 'parameter_value': '84.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-01T15:00:00Z', 'parameter_value': '28.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-01T15:00:00Z', 'parameter_value': '5.0', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-01T15:30:00Z', 'parameter_value': '-14.7', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-01T15:30:00Z', 'parameter_value': '84.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-01T15:30:00Z', 'parameter_value': '28.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-01T15:30:00Z', 'parameter_value': '6.0', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-01T16:00:00Z', 'parameter_value': '-14.9', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-01T16:00:00Z', 'parameter_value': '84.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-01T16:00:00Z', 'parameter_value': '30.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-01T16:00:00Z', 'parameter_value': '5.6', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-01T16:30:00Z', 'parameter_value': '-15.0', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-01T16:30:00Z', 'parameter_value': '84.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-01T16:30:00Z', 'parameter_value': '30.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-01T16:30:00Z', 'parameter_value': '5.2', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-01T17:00:00Z', 'parameter_value': '-15.4', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-01T17:00:00Z', 'parameter_value': '84.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-01T17:00:00Z', 'parameter_value': '31.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-01T17:00:00Z', 'parameter_value': '4.8', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-01T17:30:00Z', 'parameter_value': '-15.8', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-01T17:30:00Z', 'parameter_value': '84.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-01T17:30:00Z', 'parameter_value': '27.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-01T17:30:00Z', 'parameter_value': '5.2', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-01T18:00:00Z', 'parameter_value': '-16.1', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-01T18:00:00Z', 'parameter_value': '84.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-01T18:00:00Z', 'parameter_value': '24.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-01T18:00:00Z', 'parameter_value': '4.8', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-01T18:30:00Z', 'parameter_value': '-16.6', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-01T18:30:00Z', 'parameter_value': '83.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-01T18:30:00Z', 'parameter_value': '25.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-01T18:30:00Z', 'parameter_value': '5.3', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-01T19:00:00Z', 'parameter_value': '-16.9', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-01T19:00:00Z', 'parameter_value': '83.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-01T19:00:00Z', 'parameter_value': '24.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-01T19:00:00Z', 'parameter_value': '4.1', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-01T19:30:00Z', 'parameter_value': '-17.1', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-01T19:30:00Z', 'parameter_value': '83.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-01T19:30:00Z', 'parameter_value': '25.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-01T19:30:00Z', 'parameter_value': '4.6', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-01T20:00:00Z', 'parameter_value': '-17.2', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-01T20:00:00Z', 'parameter_value': '83.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-01T20:00:00Z', 'parameter_value': '22.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-01T20:00:00Z', 'parameter_value': '5.3', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-01T20:30:00Z', 'parameter_value': '-17.6', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-01T20:30:00Z', 'parameter_value': '83.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-01T20:30:00Z', 'parameter_value': '16.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-01T20:30:00Z', 'parameter_value': '5.2', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-01T21:00:00Z', 'parameter_value': '-17.9', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-01T21:00:00Z', 'parameter_value': '83.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-01T21:00:00Z', 'parameter_value': '18.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-01T21:00:00Z', 'parameter_value': '4.4', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-01T21:30:00Z', 'parameter_value': '-18.2', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-01T21:30:00Z', 'parameter_value': '82.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-01T21:30:00Z', 'parameter_value': '16.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-01T21:30:00Z', 'parameter_value': '4.8', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-01T22:00:00Z', 'parameter_value': '-18.6', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-01T22:00:00Z', 'parameter_value': '82.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-01T22:00:00Z', 'parameter_value': '14.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-01T22:00:00Z', 'parameter_value': '4.7', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-01T22:30:00Z', 'parameter_value': '-18.8', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-01T22:30:00Z', 'parameter_value': '82.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-01T22:30:00Z', 'parameter_value': '12.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-01T22:30:00Z', 'parameter_value': '4.8', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-01T23:00:00Z', 'parameter_value': '-19.0', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-01T23:00:00Z', 'parameter_value': '82.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-01T23:00:00Z', 'parameter_value': '10.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-01T23:00:00Z', 'parameter_value': '5.1', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-01T23:30:00Z', 'parameter_value': '-19.1', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-01T23:30:00Z', 'parameter_value': '81.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-01T23:30:00Z', 'parameter_value': '5.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-01T23:30:00Z', 'parameter_value': '4.7', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-02T00:00:00Z', 'parameter_value': '-19.4', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-02T00:00:00Z', 'parameter_value': '81.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-02T00:00:00Z', 'parameter_value': '11.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-02T00:00:00Z', 'parameter_value': '4.1', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-02T00:30:00Z', 'parameter_value': '-19.4', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-02T00:30:00Z', 'parameter_value': '81.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-02T00:30:00Z', 'parameter_value': '10.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-02T00:30:00Z', 'parameter_value': '5.0', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-02T01:00:00Z', 'parameter_value': '-19.5', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-02T01:00:00Z', 'parameter_value': '81.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-02T01:00:00Z', 'parameter_value': '9.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-02T01:00:00Z', 'parameter_value': '4.8', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-02T01:30:00Z', 'parameter_value': '-19.6', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-02T01:30:00Z', 'parameter_value': '82.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-02T01:30:00Z', 'parameter_value': '13.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-02T01:30:00Z', 'parameter_value': '4.1', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-02T02:00:00Z', 'parameter_value': '-18.9', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-02T02:00:00Z', 'parameter_value': '81.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-02T02:00:00Z', 'parameter_value': '14.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-02T02:00:00Z', 'parameter_value': '3.8', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-02T02:30:00Z', 'parameter_value': '-18.6', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-02T02:30:00Z', 'parameter_value': '81.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-02T02:30:00Z', 'parameter_value': '9.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-02T02:30:00Z', 'parameter_value': '3.9', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-02T03:00:00Z', 'parameter_value': '-18.2', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-02T03:00:00Z', 'parameter_value': '81.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-02T03:00:00Z', 'parameter_value': '5.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-02T03:00:00Z', 'parameter_value': '4.2', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-02T03:30:00Z', 'parameter_value': '-17.9', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-02T03:30:00Z', 'parameter_value': '81.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-02T03:30:00Z', 'parameter_value': '11.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-02T03:30:00Z', 'parameter_value': '4.3', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-02T04:00:00Z', 'parameter_value': '-17.6', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-02T04:00:00Z', 'parameter_value': '81.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-02T04:00:00Z', 'parameter_value': '15.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-02T04:00:00Z', 'parameter_value': '4.7', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-02T04:30:00Z', 'parameter_value': '-17.3', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-02T04:30:00Z', 'parameter_value': '81.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-02T04:30:00Z', 'parameter_value': '14.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-02T04:30:00Z', 'parameter_value': '5.3', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-02T05:00:00Z', 'parameter_value': '-17.1', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-02T05:00:00Z', 'parameter_value': '81.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-02T05:00:00Z', 'parameter_value': '17.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-02T05:00:00Z', 'parameter_value': '4.5', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-02T05:30:00Z', 'parameter_value': '-17.0', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-02T05:30:00Z', 'parameter_value': '81.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-02T05:30:00Z', 'parameter_value': '15.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-02T05:30:00Z', 'parameter_value': '4.1', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-02T06:00:00Z', 'parameter_value': '-16.8', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-02T06:00:00Z', 'parameter_value': '81.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-02T06:00:00Z', 'parameter_value': '18.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-02T06:00:00Z', 'parameter_value': '3.6', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-02T06:30:00Z', 'parameter_value': '-16.7', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-02T06:30:00Z', 'parameter_value': '81.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-02T06:30:00Z', 'parameter_value': '19.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-02T06:30:00Z', 'parameter_value': '3.4', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-02T07:00:00Z', 'parameter_value': '-16.7', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-02T07:00:00Z', 'parameter_value': '82.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-02T07:00:00Z', 'parameter_value': '10.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-02T07:00:00Z', 'parameter_value': '4.8', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-02T07:30:00Z', 'parameter_value': '-16.7', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-02T07:30:00Z', 'parameter_value': '81.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-02T07:30:00Z', 'parameter_value': '20.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-02T07:30:00Z', 'parameter_value': '4.8', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-02T08:00:00Z', 'parameter_value': '-17.1', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-02T08:00:00Z', 'parameter_value': '81.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-02T08:00:00Z', 'parameter_value': '29.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-02T08:00:00Z', 'parameter_value': '4.5', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-02T08:30:00Z', 'parameter_value': '-17.3', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-02T08:30:00Z', 'parameter_value': '82.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-02T08:30:00Z', 'parameter_value': '21.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-02T08:30:00Z', 'parameter_value': '4.2', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-02T09:00:00Z', 'parameter_value': '-17.3', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-02T09:00:00Z', 'parameter_value': '83.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-02T09:00:00Z', 'parameter_value': '22.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-02T09:00:00Z', 'parameter_value': '4.9', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-02T09:30:00Z', 'parameter_value': '-17.1', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-02T09:30:00Z', 'parameter_value': '82.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-02T09:30:00Z', 'parameter_value': '24.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-02T09:30:00Z', 'parameter_value': '3.7', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-02T10:00:00Z', 'parameter_value': '-16.8', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-02T10:00:00Z', 'parameter_value': '82.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-02T10:00:00Z', 'parameter_value': '13.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-02T10:00:00Z', 'parameter_value': '5.3', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-02T10:30:00Z', 'parameter_value': '-16.3', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-02T10:30:00Z', 'parameter_value': '81.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-02T10:30:00Z', 'parameter_value': '16.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-02T10:30:00Z', 'parameter_value': '4.2', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-02T11:00:00Z', 'parameter_value': '-15.9', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-02T11:00:00Z', 'parameter_value': '80.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-02T11:00:00Z', 'parameter_value': '15.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-02T11:00:00Z', 'parameter_value': '4.7', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-02T11:30:00Z', 'parameter_value': '-15.8', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-02T11:30:00Z', 'parameter_value': '80.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-02T11:30:00Z', 'parameter_value': '8.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-02T11:30:00Z', 'parameter_value': '4.3', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-02T12:00:00Z', 'parameter_value': '-15.8', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-02T12:00:00Z', 'parameter_value': '80.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-02T12:00:00Z', 'parameter_value': '359.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-02T12:00:00Z', 'parameter_value': '3.4', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-02T12:30:00Z', 'parameter_value': '-15.8', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-02T12:30:00Z', 'parameter_value': '81.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-02T12:30:00Z', 'parameter_value': '357.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-02T12:30:00Z', 'parameter_value': '3.0', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-02T13:00:00Z', 'parameter_value': '-15.9', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-02T13:00:00Z', 'parameter_value': '81.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-02T13:00:00Z', 'parameter_value': '356.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-02T13:00:00Z', 'parameter_value': '3.2', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-02T13:30:00Z', 'parameter_value': '-16.2', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-02T13:30:00Z', 'parameter_value': '82.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-02T13:30:00Z', 'parameter_value': '356.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-02T13:30:00Z', 'parameter_value': '2.9', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-02T14:00:00Z', 'parameter_value': '-16.3', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-02T14:00:00Z', 'parameter_value': '83.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-02T14:00:00Z', 'parameter_value': '1.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-02T14:00:00Z', 'parameter_value': '3.2', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-02T14:30:00Z', 'parameter_value': '-16.7', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-02T14:30:00Z', 'parameter_value': '83.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-02T14:30:00Z', 'parameter_value': '348.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-02T14:30:00Z', 'parameter_value': '3.1', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-02T15:00:00Z', 'parameter_value': '-16.7', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-02T15:00:00Z', 'parameter_value': '84.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-02T15:00:00Z', 'parameter_value': '354.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-02T15:00:00Z', 'parameter_value': '3.4', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-02T15:30:00Z', 'parameter_value': '-17.0', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-02T15:30:00Z', 'parameter_value': '84.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-02T15:30:00Z', 'parameter_value': '354.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-02T15:30:00Z', 'parameter_value': '3.2', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-02T16:00:00Z', 'parameter_value': '-17.1', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-02T16:00:00Z', 'parameter_value': '84.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-02T16:00:00Z', 'parameter_value': '352.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-02T16:00:00Z', 'parameter_value': '3.2', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-02T16:30:00Z', 'parameter_value': '-17.5', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-02T16:30:00Z', 'parameter_value': '84.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-02T16:30:00Z', 'parameter_value': '350.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-02T16:30:00Z', 'parameter_value': '2.7', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-02T17:00:00Z', 'parameter_value': '-17.9', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-02T17:00:00Z', 'parameter_value': '84.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-02T17:00:00Z', 'parameter_value': '350.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-02T17:00:00Z', 'parameter_value': '2.4', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-02T17:30:00Z', 'parameter_value': '-18.0', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-02T17:30:00Z', 'parameter_value': '85.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-02T17:30:00Z', 'parameter_value': '359.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-02T17:30:00Z', 'parameter_value': '2.7', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-02T18:00:00Z', 'parameter_value': '-18.3', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-02T18:00:00Z', 'parameter_value': '86.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-02T18:00:00Z', 'parameter_value': '350.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-02T18:00:00Z', 'parameter_value': '2.5', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-02T18:30:00Z', 'parameter_value': '-18.3', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-02T18:30:00Z', 'parameter_value': '86.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-02T18:30:00Z', 'parameter_value': '351.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-02T18:30:00Z', 'parameter_value': '2.9', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-02T19:00:00Z', 'parameter_value': '-18.6', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-02T19:00:00Z', 'parameter_value': '85.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-02T19:00:00Z', 'parameter_value': '354.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-02T19:00:00Z', 'parameter_value': '2.5', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-02T19:30:00Z', 'parameter_value': '-18.9', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-02T19:30:00Z', 'parameter_value': '86.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-02T19:30:00Z', 'parameter_value': '344.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-02T19:30:00Z', 'parameter_value': '2.5', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-02T20:00:00Z', 'parameter_value': '-19.4', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-02T20:00:00Z', 'parameter_value': '85.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-02T20:00:00Z', 'parameter_value': '339.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-02T20:00:00Z', 'parameter_value': '2.7', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-02T20:30:00Z', 'parameter_value': '-19.0', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-02T20:30:00Z', 'parameter_value': '85.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-02T20:30:00Z', 'parameter_value': '346.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-02T20:30:00Z', 'parameter_value': '3.2', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-02T21:00:00Z', 'parameter_value': '-19.2', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-02T21:00:00Z', 'parameter_value': '84.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-02T21:00:00Z', 'parameter_value': '348.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-02T21:00:00Z', 'parameter_value': '2.6', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-02T21:30:00Z', 'parameter_value': '-19.5', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-02T21:30:00Z', 'parameter_value': '84.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-02T21:30:00Z', 'parameter_value': '344.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-02T21:30:00Z', 'parameter_value': '3.2', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-02T22:00:00Z', 'parameter_value': '-19.6', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-02T22:00:00Z', 'parameter_value': '84.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-02T22:00:00Z', 'parameter_value': '340.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-02T22:00:00Z', 'parameter_value': '3.4', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-02T22:30:00Z', 'parameter_value': '-19.7', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-02T22:30:00Z', 'parameter_value': '83.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-02T22:30:00Z', 'parameter_value': '344.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-02T22:30:00Z', 'parameter_value': '3.3', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-02T23:00:00Z', 'parameter_value': '-19.9', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-02T23:00:00Z', 'parameter_value': '83.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-02T23:00:00Z', 'parameter_value': '345.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-02T23:00:00Z', 'parameter_value': '3.0', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-02T23:30:00Z', 'parameter_value': '-20.2', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-02T23:30:00Z', 'parameter_value': '82.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-02T23:30:00Z', 'parameter_value': '350.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-02T23:30:00Z', 'parameter_value': '2.4', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-03T00:00:00Z', 'parameter_value': '-20.4', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-03T00:00:00Z', 'parameter_value': '83.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-03T00:00:00Z', 'parameter_value': '343.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-03T00:00:00Z', 'parameter_value': '2.0', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-03T00:30:00Z', 'parameter_value': '-21.2', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-03T00:30:00Z', 'parameter_value': '83.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-03T00:30:00Z', 'parameter_value': '338.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-03T00:30:00Z', 'parameter_value': '2.2', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-03T01:00:00Z', 'parameter_value': '-21.6', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-03T01:00:00Z', 'parameter_value': '83.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-03T01:00:00Z', 'parameter_value': '329.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-03T01:00:00Z', 'parameter_value': '2.2', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-03T01:30:00Z', 'parameter_value': '-21.6', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-03T01:30:00Z', 'parameter_value': '84.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-03T01:30:00Z', 'parameter_value': '333.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-03T01:30:00Z', 'parameter_value': '2.6', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-03T02:00:00Z', 'parameter_value': '-21.9', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-03T02:00:00Z', 'parameter_value': '83.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-03T02:00:00Z', 'parameter_value': '331.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-03T02:00:00Z', 'parameter_value': '2.4', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-03T02:30:00Z', 'parameter_value': '-20.7', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-03T02:30:00Z', 'parameter_value': '84.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-03T02:30:00Z', 'parameter_value': '343.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-03T02:30:00Z', 'parameter_value': '2.2', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-03T03:00:00Z', 'parameter_value': '-21.1', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-03T03:00:00Z', 'parameter_value': '82.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-03T03:00:00Z', 'parameter_value': '341.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-03T03:00:00Z', 'parameter_value': '1.6', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-03T03:30:00Z', 'parameter_value': '-21.8', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-03T03:30:00Z', 'parameter_value': '83.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-03T03:30:00Z', 'parameter_value': '326.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-03T03:30:00Z', 'parameter_value': '2.3', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-03T04:00:00Z', 'parameter_value': '-21.9', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-03T04:00:00Z', 'parameter_value': '84.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-03T04:00:00Z', 'parameter_value': '322.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-03T04:00:00Z', 'parameter_value': '2.6', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-03T04:30:00Z', 'parameter_value': '-21.8', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-03T04:30:00Z', 'parameter_value': '83.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-03T04:30:00Z', 'parameter_value': '337.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-03T04:30:00Z', 'parameter_value': '1.9', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-03T05:00:00Z', 'parameter_value': '-22.1', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-03T05:00:00Z', 'parameter_value': '83.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-03T05:00:00Z', 'parameter_value': '328.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-03T05:00:00Z', 'parameter_value': '1.9', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-03T05:30:00Z', 'parameter_value': '-21.9', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-03T05:30:00Z', 'parameter_value': '85.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-03T05:30:00Z', 'parameter_value': '351.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-03T05:30:00Z', 'parameter_value': '1.3', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-03T06:00:00Z', 'parameter_value': '-21.5', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-03T06:00:00Z', 'parameter_value': '84.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-03T06:00:00Z', 'parameter_value': '322.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-03T06:00:00Z', 'parameter_value': '2.9', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-03T06:30:00Z', 'parameter_value': '-21.9', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-03T06:30:00Z', 'parameter_value': '83.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-03T06:30:00Z', 'parameter_value': '316.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-03T06:30:00Z', 'parameter_value': '2.4', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-03T07:00:00Z', 'parameter_value': '-22.1', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-03T07:00:00Z', 'parameter_value': '83.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-03T07:00:00Z', 'parameter_value': '1.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-03T07:00:00Z', 'parameter_value': '0.8', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-03T07:30:00Z', 'parameter_value': '-21.4', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-03T07:30:00Z', 'parameter_value': '84.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-03T07:30:00Z', 'parameter_value': '0.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-03T07:30:00Z', 'parameter_value': '0.0', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-03T08:00:00Z', 'parameter_value': '-20.7', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-03T08:00:00Z', 'parameter_value': '83.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-03T08:00:00Z', 'parameter_value': '0.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-03T08:00:00Z', 'parameter_value': '0.0', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-03T08:30:00Z', 'parameter_value': '-19.6', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-03T08:30:00Z', 'parameter_value': '83.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-03T08:30:00Z', 'parameter_value': '0.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-03T08:30:00Z', 'parameter_value': '0.0', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-03T09:00:00Z', 'parameter_value': '-19.0', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-03T09:00:00Z', 'parameter_value': '83.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-03T09:00:00Z', 'parameter_value': '218.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-03T09:00:00Z', 'parameter_value': '1.1', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-03T09:30:00Z', 'parameter_value': '-17.8', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-03T09:30:00Z', 'parameter_value': '85.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-03T09:30:00Z', 'parameter_value': '243.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-03T09:30:00Z', 'parameter_value': '2.2', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-03T10:00:00Z', 'parameter_value': '-15.8', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-03T10:00:00Z', 'parameter_value': '85.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-03T10:00:00Z', 'parameter_value': '255.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-03T10:00:00Z', 'parameter_value': '2.4', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-03T10:30:00Z', 'parameter_value': '-15.0', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-03T10:30:00Z', 'parameter_value': '84.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-03T10:30:00Z', 'parameter_value': '250.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-03T10:30:00Z', 'parameter_value': '3.7', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-03T11:00:00Z', 'parameter_value': '-14.1', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-03T11:00:00Z', 'parameter_value': '85.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-03T11:00:00Z', 'parameter_value': '229.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-03T11:00:00Z', 'parameter_value': '3.1', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-03T11:30:00Z', 'parameter_value': '-13.1', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-03T11:30:00Z', 'parameter_value': '87.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-03T11:30:00Z', 'parameter_value': '214.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-03T11:30:00Z', 'parameter_value': '3.8', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-03T12:00:00Z', 'parameter_value': '-11.7', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-03T12:00:00Z', 'parameter_value': '89.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-03T12:00:00Z', 'parameter_value': '208.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-03T12:00:00Z', 'parameter_value': '2.6', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-03T12:30:00Z', 'parameter_value': '-11.6', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-03T12:30:00Z', 'parameter_value': '89.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-01-03T12:30:00Z', 'parameter_value': '186.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-01-03T12:30:00Z', 'parameter_value': '1.9', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-01-03T13:00:00Z', 'parameter_value': '-9.8', 'parameter_name': 'temperature'}
# {'timestamp': '2010-01-03T13:00:00Z', 'parameter_value': '92.0', 'parameter_name': 'humidity'}
# ...
# {'timestamp': '2010-02-28T03:30:00Z', 'parameter_value': '99.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-02-28T03:30:00Z', 'parameter_value': '218.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-02-28T03:30:00Z', 'parameter_value': '5.6', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-02-28T04:00:00Z', 'parameter_value': '0.3', 'parameter_name': 'temperature'}
# {'timestamp': '2010-02-28T04:00:00Z', 'parameter_value': '99.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-02-28T04:00:00Z', 'parameter_value': '215.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-02-28T04:00:00Z', 'parameter_value': '4.3', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-02-28T04:30:00Z', 'parameter_value': '0.4', 'parameter_name': 'temperature'}
# {'timestamp': '2010-02-28T04:30:00Z', 'parameter_value': '99.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-02-28T04:30:00Z', 'parameter_value': '211.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-02-28T04:30:00Z', 'parameter_value': '4.3', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-02-28T05:00:00Z', 'parameter_value': '0.5', 'parameter_name': 'temperature'}
# {'timestamp': '2010-02-28T05:00:00Z', 'parameter_value': '99.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-02-28T05:00:00Z', 'parameter_value': '212.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-02-28T05:00:00Z', 'parameter_value': '3.8', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-02-28T05:30:00Z', 'parameter_value': '0.5', 'parameter_name': 'temperature'}
# {'timestamp': '2010-02-28T05:30:00Z', 'parameter_value': '99.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-02-28T05:30:00Z', 'parameter_value': '183.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-02-28T05:30:00Z', 'parameter_value': '3.5', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-02-28T06:00:00Z', 'parameter_value': '0.5', 'parameter_name': 'temperature'}
# {'timestamp': '2010-02-28T06:00:00Z', 'parameter_value': '99.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-02-28T06:00:00Z', 'parameter_value': '185.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-02-28T06:00:00Z', 'parameter_value': '4.2', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-02-28T06:30:00Z', 'parameter_value': '0.7', 'parameter_name': 'temperature'}
# {'timestamp': '2010-02-28T06:30:00Z', 'parameter_value': '99.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-02-28T06:30:00Z', 'parameter_value': '178.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-02-28T06:30:00Z', 'parameter_value': '3.6', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-02-28T07:00:00Z', 'parameter_value': '0.9', 'parameter_name': 'temperature'}
# {'timestamp': '2010-02-28T07:00:00Z', 'parameter_value': '99.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-02-28T07:00:00Z', 'parameter_value': '179.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-02-28T07:00:00Z', 'parameter_value': '5.7', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-02-28T07:30:00Z', 'parameter_value': '1.0', 'parameter_name': 'temperature'}
# {'timestamp': '2010-02-28T07:30:00Z', 'parameter_value': '99.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-02-28T07:30:00Z', 'parameter_value': '177.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-02-28T07:30:00Z', 'parameter_value': '4.9', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-02-28T08:00:00Z', 'parameter_value': '1.0', 'parameter_name': 'temperature'}
# {'timestamp': '2010-02-28T08:00:00Z', 'parameter_value': '99.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-02-28T08:00:00Z', 'parameter_value': '171.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-02-28T08:00:00Z', 'parameter_value': '4.4', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-02-28T08:30:00Z', 'parameter_value': '1.0', 'parameter_name': 'temperature'}
# {'timestamp': '2010-02-28T08:30:00Z', 'parameter_value': '98.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-02-28T08:30:00Z', 'parameter_value': '177.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-02-28T08:30:00Z', 'parameter_value': '5.7', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-02-28T09:00:00Z', 'parameter_value': '1.2', 'parameter_name': 'temperature'}
# {'timestamp': '2010-02-28T09:00:00Z', 'parameter_value': '98.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-02-28T09:00:00Z', 'parameter_value': '179.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-02-28T09:00:00Z', 'parameter_value': '4.3', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-02-28T09:30:00Z', 'parameter_value': '1.2', 'parameter_name': 'temperature'}
# {'timestamp': '2010-02-28T09:30:00Z', 'parameter_value': '97.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-02-28T09:30:00Z', 'parameter_value': '175.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-02-28T09:30:00Z', 'parameter_value': '4.8', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-02-28T10:00:00Z', 'parameter_value': '1.1', 'parameter_name': 'temperature'}
# {'timestamp': '2010-02-28T10:00:00Z', 'parameter_value': '97.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-02-28T10:00:00Z', 'parameter_value': '183.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-02-28T10:00:00Z', 'parameter_value': '4.7', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-02-28T10:30:00Z', 'parameter_value': '1.1', 'parameter_name': 'temperature'}
# {'timestamp': '2010-02-28T10:30:00Z', 'parameter_value': '97.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-02-28T10:30:00Z', 'parameter_value': '169.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-02-28T10:30:00Z', 'parameter_value': '3.5', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-02-28T11:00:00Z', 'parameter_value': '1.2', 'parameter_name': 'temperature'}
# {'timestamp': '2010-02-28T11:00:00Z', 'parameter_value': '97.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-02-28T11:00:00Z', 'parameter_value': '179.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-02-28T11:00:00Z', 'parameter_value': '4.2', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-02-28T11:30:00Z', 'parameter_value': '1.1', 'parameter_name': 'temperature'}
# {'timestamp': '2010-02-28T11:30:00Z', 'parameter_value': '97.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-02-28T11:30:00Z', 'parameter_value': '172.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-02-28T11:30:00Z', 'parameter_value': '4.0', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-02-28T12:00:00Z', 'parameter_value': '1.2', 'parameter_name': 'temperature'}
# {'timestamp': '2010-02-28T12:00:00Z', 'parameter_value': '96.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-02-28T12:00:00Z', 'parameter_value': '160.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-02-28T12:00:00Z', 'parameter_value': '4.9', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-02-28T12:30:00Z', 'parameter_value': '1.2', 'parameter_name': 'temperature'}
# {'timestamp': '2010-02-28T12:30:00Z', 'parameter_value': '96.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-02-28T12:30:00Z', 'parameter_value': '163.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-02-28T12:30:00Z', 'parameter_value': '4.8', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-02-28T13:00:00Z', 'parameter_value': '1.3', 'parameter_name': 'temperature'}
# {'timestamp': '2010-02-28T13:00:00Z', 'parameter_value': '95.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-02-28T13:00:00Z', 'parameter_value': '166.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-02-28T13:00:00Z', 'parameter_value': '5.1', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-02-28T13:30:00Z', 'parameter_value': '1.0', 'parameter_name': 'temperature'}
# {'timestamp': '2010-02-28T13:30:00Z', 'parameter_value': '95.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-02-28T13:30:00Z', 'parameter_value': '168.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-02-28T13:30:00Z', 'parameter_value': '5.2', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-02-28T14:00:00Z', 'parameter_value': '1.1', 'parameter_name': 'temperature'}
# {'timestamp': '2010-02-28T14:00:00Z', 'parameter_value': '95.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-02-28T14:00:00Z', 'parameter_value': '158.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-02-28T14:00:00Z', 'parameter_value': '5.2', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-02-28T14:30:00Z', 'parameter_value': '1.0', 'parameter_name': 'temperature'}
# {'timestamp': '2010-02-28T14:30:00Z', 'parameter_value': '95.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-02-28T14:30:00Z', 'parameter_value': '166.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-02-28T14:30:00Z', 'parameter_value': '4.9', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-02-28T15:00:00Z', 'parameter_value': '0.8', 'parameter_name': 'temperature'}
# {'timestamp': '2010-02-28T15:00:00Z', 'parameter_value': '96.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-02-28T15:00:00Z', 'parameter_value': '164.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-02-28T15:00:00Z', 'parameter_value': '5.0', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-02-28T15:30:00Z', 'parameter_value': '0.9', 'parameter_name': 'temperature'}
# {'timestamp': '2010-02-28T15:30:00Z', 'parameter_value': '96.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-02-28T15:30:00Z', 'parameter_value': '164.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-02-28T15:30:00Z', 'parameter_value': '5.8', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-02-28T16:00:00Z', 'parameter_value': '0.9', 'parameter_name': 'temperature'}
# {'timestamp': '2010-02-28T16:00:00Z', 'parameter_value': '96.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-02-28T16:00:00Z', 'parameter_value': '162.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-02-28T16:00:00Z', 'parameter_value': '5.0', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-02-28T16:30:00Z', 'parameter_value': '0.8', 'parameter_name': 'temperature'}
# {'timestamp': '2010-02-28T16:30:00Z', 'parameter_value': '96.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-02-28T16:30:00Z', 'parameter_value': '178.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-02-28T16:30:00Z', 'parameter_value': '5.3', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-02-28T17:00:00Z', 'parameter_value': '0.6', 'parameter_name': 'temperature'}
# {'timestamp': '2010-02-28T17:00:00Z', 'parameter_value': '97.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-02-28T17:00:00Z', 'parameter_value': '177.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-02-28T17:00:00Z', 'parameter_value': '5.0', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-02-28T17:30:00Z', 'parameter_value': '0.5', 'parameter_name': 'temperature'}
# {'timestamp': '2010-02-28T17:30:00Z', 'parameter_value': '97.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-02-28T17:30:00Z', 'parameter_value': '173.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-02-28T17:30:00Z', 'parameter_value': '4.4', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-02-28T18:00:00Z', 'parameter_value': '0.7', 'parameter_name': 'temperature'}
# {'timestamp': '2010-02-28T18:00:00Z', 'parameter_value': '97.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-02-28T18:00:00Z', 'parameter_value': '181.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-02-28T18:00:00Z', 'parameter_value': '3.7', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-02-28T18:30:00Z', 'parameter_value': '0.9', 'parameter_name': 'temperature'}
# {'timestamp': '2010-02-28T18:30:00Z', 'parameter_value': '97.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-02-28T18:30:00Z', 'parameter_value': '176.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-02-28T18:30:00Z', 'parameter_value': '3.7', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-02-28T19:00:00Z', 'parameter_value': '0.9', 'parameter_name': 'temperature'}
# {'timestamp': '2010-02-28T19:00:00Z', 'parameter_value': '97.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-02-28T19:00:00Z', 'parameter_value': '185.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-02-28T19:00:00Z', 'parameter_value': '4.5', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-02-28T19:30:00Z', 'parameter_value': '1.1', 'parameter_name': 'temperature'}
# {'timestamp': '2010-02-28T19:30:00Z', 'parameter_value': '97.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-02-28T19:30:00Z', 'parameter_value': '194.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-02-28T19:30:00Z', 'parameter_value': '5.1', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-02-28T20:00:00Z', 'parameter_value': '1.1', 'parameter_name': 'temperature'}
# {'timestamp': '2010-02-28T20:00:00Z', 'parameter_value': '97.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-02-28T20:00:00Z', 'parameter_value': '191.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-02-28T20:00:00Z', 'parameter_value': '4.4', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-02-28T20:30:00Z', 'parameter_value': '1.2', 'parameter_name': 'temperature'}
# {'timestamp': '2010-02-28T20:30:00Z', 'parameter_value': '96.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-02-28T20:30:00Z', 'parameter_value': '193.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-02-28T20:30:00Z', 'parameter_value': '5.1', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-02-28T21:00:00Z', 'parameter_value': '1.1', 'parameter_name': 'temperature'}
# {'timestamp': '2010-02-28T21:00:00Z', 'parameter_value': '96.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-02-28T21:00:00Z', 'parameter_value': '192.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-02-28T21:00:00Z', 'parameter_value': '3.6', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-02-28T21:30:00Z', 'parameter_value': '1.2', 'parameter_name': 'temperature'}
# {'timestamp': '2010-02-28T21:30:00Z', 'parameter_value': '95.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-02-28T21:30:00Z', 'parameter_value': '195.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-02-28T21:30:00Z', 'parameter_value': '3.8', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-02-28T22:00:00Z', 'parameter_value': '1.1', 'parameter_name': 'temperature'}
# {'timestamp': '2010-02-28T22:00:00Z', 'parameter_value': '95.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-02-28T22:00:00Z', 'parameter_value': '201.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-02-28T22:00:00Z', 'parameter_value': '3.7', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-02-28T22:30:00Z', 'parameter_value': '1.1', 'parameter_name': 'temperature'}
# {'timestamp': '2010-02-28T22:30:00Z', 'parameter_value': '96.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-02-28T22:30:00Z', 'parameter_value': '190.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-02-28T22:30:00Z', 'parameter_value': '3.3', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-02-28T23:00:00Z', 'parameter_value': '1.1', 'parameter_name': 'temperature'}
# {'timestamp': '2010-02-28T23:00:00Z', 'parameter_value': '95.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-02-28T23:00:00Z', 'parameter_value': '176.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-02-28T23:00:00Z', 'parameter_value': '2.9', 'parameter_name': 'windspeedms'}
# {'timestamp': '2010-02-28T23:30:00Z', 'parameter_value': '0.9', 'parameter_name': 'temperature'}
# {'timestamp': '2010-02-28T23:30:00Z', 'parameter_value': '96.0', 'parameter_name': 'humidity'}
# {'timestamp': '2010-02-28T23:30:00Z', 'parameter_value': '145.0', 'parameter_name': 'winddirection'}
# {'timestamp': '2010-02-28T23:30:00Z', 'parameter_value': '3.2', 'parameter_name': 'windspeedms'}
# loop completed

# %%
keys = ['ensimmäinen', 'toinen', 'kolmas']
values = [12.6, 23, 4, 0.6]

measure = {}
measure = {k:v for k, v in zip(keys, values)}
print(measure)
# Out:
# {'kolmas': 4, 'ensimm\xc3\xa4inen': 12.6, 'toinen': 23}
